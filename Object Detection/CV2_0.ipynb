# %%
from google.colab import drive
drive.mount('/content/drive')
# /content/drive/MyDrive/BrainHack/datasets/images
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/Brainhack')
# !ls
# Out:
# CV_colab_dataset.yaml  CV_val_dataset.yaml  reannotate.py  yolov8m.pt
# CV_dataset.yaml        datasets		    runs	   yolov8n.pt

# %%
# !pip install ultralytics #install ultralytics for yolov8
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 592.7/592.7 kB 24.5 MB/s eta 0:00:00
# ...

# %%
# !python3 reannotate.py #reannotates class labels for train and val to 0
# Out:
# /content/drive/MyDrive/Brainhack/datasets/labels/valSet/image_0000.txt
# ['0', '0.08016566657742966', '0.6518675703938716', '0.13887016521022694', '0.22731556558368438\n']
# ['1', '0.30986576973822477', '0.6840537125350188', '0.07954158402965454', '0.18207647517487363\n']
# ['2', '0.5148032983727551', '0.7343331464519938', '0.1314237503107072', '0.20257024949377112\n']
# /content/drive/MyDrive/Brainhack/datasets/labels/valSet/image_0016.txt
# ['0', '0.8931451612903223', '0.7974910394265232', '0.2137096774193545', '0.26164874551971357\n']
# /content/drive/MyDrive/Brainhack/datasets/labels/valSet/image_0020.txt
# ['0', '0.8301748917538202', '0.7706050371024097', '0.19771569604754066', '0.24804066313833364\n']
# ['5', '0.39563155985908216', '0.7622446897868237', '0.1395180558845598', '0.2604568569854873\n']
# /content/drive/MyDrive/Brainhack/datasets/labels/valSet/image_0012.txt
# ['0', '0.9279233870967732', '0.719368984179901', '0.12600806451612848', '0.27612711778467774\n']
# ...

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="CV_dataset.yaml", epochs=50)  # train the model
# metrics = model.val()  # evaluate model performance on the validation set
# success = model.export(format="onnx")  # export the model to ONNX format
# metrics = model.val(data="CV_val_dataset.yaml") #validate on train set
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.predict(source="/content/drive/MyDrive/Brainhack/datasets/images/testSet", save=True) #testing against test set
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0000.png: 384x640 3 toys, 25.8ms
# image 2/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0001.png: 384x640 3 toys, 25.8ms
# image 3/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0002.png: 384x640 3 toys, 25.8ms
# ...
