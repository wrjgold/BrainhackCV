# %%
from google.colab import drive
drive.mount('/content/drive')
# /content/drive/MyDrive/BrainHack/datasets/images
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/Brainhack')
# !ls
# Out:
# CV_colab_dataset.yaml  datasets  yolov8m.pt
# CV_val_dataset.yaml    runs	 yolov8n.pt

# %%
# !pip install ultralytics #install ultralytics for yolov8
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 592.7/592.7 kB 9.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="CV_colab_dataset.yaml", epochs=30, patience=20, dropout=0.2)  # train the model
# metrics = model.val()  # evaluate model performance on the validation set
#results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
# success = model.export(format="onnx")  # export the model to ONNX format
metrics = model.val(data="CV_val_dataset.yaml") #validate on train set
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
os.chdir("runs/detect/train2/weights")

# %%
best = YOLO("best.pt") #loading pretrained YOLO model
results = best.predict(source="/content/drive/MyDrive/Brainhack/datasets/images/testSet", save=True,save_txt=True,conf=0.4) #testing against test set
# Out:
# image 17/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0016.png: 384x640 1 plushie47, 33.5ms
# image 18/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0017.png: 384x640 1 plushie73, 26.6ms
# image 19/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0018.png: 384x640 1 plushie193, 26.6ms
# image 20/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0019.png: 384x640 1 plushie14, 1 plushie88, 1 plushie122, 26.6ms
# image 21/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0020.png: 384x640 1 plushie53, 1 plushie69, 26.9ms
# image 22/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0021.png: 384x640 1 plushie69, 26.5ms
# image 23/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0022.png: 384x640 1 plushie69, 36.7ms
# image 24/1600 /content/drive/MyDrive/Brainhack/datasets/images/testSet/image_0023.png: 384x640 1 plushie69, 1 plushie160, 26.6ms
# ...

# %%
for r in results:
  boxes = r.boxes
  for box in boxes:
    x1, y1, x2, y2 = box.xyxyn[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f82178105cbf> in <cell line: 1>()
#       2   boxes = r.boxes
#       3   for box in boxes:
# ----> 4     x1, y1, x2, y2 = float(box.xyxyn[0])
#       5     print(x1,y1,x2,y2)
#
# ValueError: only one element tensors can be converted to Python scalars
